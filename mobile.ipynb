# %%
import pandas as pd
df = pd.read_csv('mobile.csv')

# %%
df
# Out:
#     score  price
# 0      60  11000
# 1      61  11500
# 2      62  12000
# 3      63  12500
# 4      64  13000
# 5      65  13500
# 6      66  14000
# 7      67  14500
# 8      68  15000
# 9      69  15500
# 10     70  16000
# 11     71  16500
# 12     72  17000
# 13     73  17500
# 14     74  18000
# 15     75  18500
# 16     76  19000
# 17     77  19500
# 18     78  20000
# 19     79  20500
# 20     80  21000
# 21     81  21500
# 22     82  22000
# 23     83  22500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   score   24 non-null     int64
#  1   price   24 non-null     int64
# dtypes: int64(2)
# memory usage: 516.0 bytes

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop('price', axis='columns'),df.price)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
df1= pd.DataFrame({'original values' : y_test, 'predict': y_pred})

# %%
#df1.to_csv('mob.csv')

# %%
#df1

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_error = mae(y_test, y_pred)

# %%
mae_error
# Out:
# 3.637978807091713e-12

# %%
y_pred
# Out:
# array([17000., 14000., 20500., 21000., 13500., 17500.])

# %%
from sklearn.metrics import mean_squared_error as mae
mae(y_test, y_pred)
# Out:
# 1.3234889800848443e-23

# %%
mae_error
# Out:
# 3.637978807091713e-12
